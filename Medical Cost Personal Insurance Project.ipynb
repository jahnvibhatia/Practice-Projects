# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:\\Users\\DELL\\Desktop\\Internship\\medical_cost_insurance.csv')
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.set()
plt.figure(figsize= (6,6))
sns.distplot(df['age'])
plt.title('age distribution')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5856\3804284864.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='sex', data = df)
plt.title('sex distribution')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
sns.set()
plt.figure(figsize= (6,6))
sns.distplot(df['bmi'])
plt.title('bmi distribution')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5856\2577007594.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bmi'])

# %%
sns.set()
plt.figure(figsize= (6,6))
sns.countplot(x = 'children', data = df)
plt.title('children count')
plt.show()

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
sns.set()
plt.figure(figsize= (6,6))
sns.countplot(x = 'smoker', data = df)
plt.title('smoker count')
plt.show()

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
sns.set()
plt.figure(figsize= (6,6))
sns.countplot(x = 'region', data = df)
plt.title('region')
plt.show()

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
sns.set()
plt.figure(figsize= (6,6))
sns.distplot(df['charges'])
plt.title('charges distribution')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5856\1264997131.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['charges'])

# %%
df.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5856\1886530979.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5856\282088417.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
c = ['sex', 'smoker', 'region']
for i in c:
    df[i] = le.fit_transform(df[i])

# %%
df.head(4)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061

# %%
sns.regplot(x='age', y='charges', data = df)
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.regplot(x='sex', y='charges', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sns.regplot(x='bmi', y='charges', data = df)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x='children', y='charges', data = df)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
sns.regplot(x='smoker', y='charges', data = df)
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
sns.regplot(x='region', y='charges', data = df)
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
col = ['age', 'sex', 'bmi', 'children', 'region', 'charges']

# %%
for c in col:
    plt.figure()
    sns.boxplot(y=c, data = df)
    plt.show()

# %%
for c in col:
    percentile25 = df[c].quantile(0.25)
    percentile75 = df[c].quantile(0.75)
    iqr = percentile75-percentile25
    upper_limit = percentile75+(1.5*iqr)
    lower_limit = percentile25-(1.5*iqr)
    df = df[df[c]>lower_limit]
    df = df[df[c]<upper_limit]

# %%
for c in col:
    plt.figure()
    sns.boxplot(y=c, data = df)
    plt.show()

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1181 rows x 7 columns]

# %%
x1 = df.drop(columns='charges',axis=1).values
y1 = df['charges'].values

from sklearn.model_selection import train_test_split

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, random_state=10)

# %%
x1_train.shape, x1_test.shape, y1_train.shape, y1_test.shape
# Out:
# ((944, 6), (237, 6), (944,), (237,))

# %%
from sklearn import linear_model

lr = linear_model.LinearRegression()

# %%
lr.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([  242.04518069,  -274.94181907,    79.33117559,   311.57412049,
#        15201.55848555,  -452.05518052])

# %%
lr.intercept_
# Out:
# -3081.6472254650507

# %%
y1_pred = lr.predict(x1_test)

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y1_test, y1_pred)
# Out:
# 21923542.471948005

# %%
np.sqrt(metrics.mean_squared_error(y1_test, y1_pred))
# Out:
# 4682.258266258708

# %%
lr.score(x1_train, y1_train)
# Out:
# 0.5888812895846541

# %%
lr.score(x1_test, y1_test)
# Out:
# 0.6445268774062194

# %%
metrics.r2_score(y1_test, y1_pred)
# Out:
# 0.6445268774062194

# %%
metrics.mean_squared_error(y1_test, y1_pred)
# Out:
# 21923542.471948005

# %%
metrics.mean_squared_error(y1_test, y1_pred)
# Out:
# 21923542.471948005

# %%
 # plt.plot(y1_test, label='original')
# plt.plot(y1_pred, label = 'predicted')
# plt.legend()
# plt.show()

# keepig this code to clear doubts about it

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1181 rows x 7 columns]

# %%
x2 = df.iloc[:,0:-1].values
y2 = df.iloc[:,-1:].values

# %%
from sklearn.preprocessing import StandardScaler

# %%
scx = StandardScaler()
scy = StandardScaler()

# %%
x2 = scx.fit_transform(x2)
y2 = scy.fit_transform(y2)

# %%
from sklearn.svm import SVR

# %%
svr2 = SVR(kernel ='rbf')

# %%
svr2.fit(x2,y2.flatten())
# Out:
# SVR()

# %%
y2_pred = svr2.predict(x2)

# %%
from sklearn.metrics import mean_squared_error

# %%
r2score = svr2.score(x2, y2)
print("R-squared:", r2score)
print("MSE:", mean_squared_error(y2, y2_pred))
# Out:
# R-squared: 0.6543586660651541
# MSE: 0.34564133393484586

# %%
metrics.r2_score(y2, y2_pred)
# Out:
# 0.6543586660651541

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1181 rows x 7 columns]

# %%
x3 = df.iloc[:,0:-1].values
y3 = df.iloc[:,-1]

# %%
x3.shape, y3.shape
# Out:
# ((1181, 6), (1181,))

# %%
x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size=0.2, random_state=10)

# %%
print(x3_train.shape, x3_test.shape, y3_train.shape, y3_test.shape)
# Out:
# (944, 6) (237, 6) (944,) (237,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc3 = StandardScaler()

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knnreg = KNeighborsRegressor(n_neighbors=5)
knnreg.fit(x3_train, y3_train)
# Out:
# KNeighborsRegressor()

# %%
knnreg.score(x3_test, y3_test)
# Out:
# 0.20061682110767542

# %%
y3_pred = knnreg.predict(x3_test)

# %%
metrics.r2_score(y3_test,y3_pred)
# Out:
# 0.20061682110767542

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1181 rows x 7 columns]

# %%
x4=df.drop(['charges'],axis=1).values
y4=df['charges'].values
x4_train,x4_test,y4_train,y4_test=train_test_split(x4,y4,test_size=0.2,random_state=10)

# %%
x4_train.shape,x4_test.shape,y4_train.shape,y4_test.shape
# Out:
# ((944, 6), (237, 6), (944,), (237,))

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()

# %%
rfr.fit(x4_train,y4_train)
# Out:
# RandomForestRegressor()

# %%
y4_pred = rfr.predict(x4_test)

# %%
metrics.r2_score(y4_test,y4_pred)
# Out:
# 0.6912502432473859

# %%
rfr.score(x4_train,y4_train)
# Out:
# 0.9394755814659609

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
x5 = df.iloc[:,0:-1].values
y5 = df.iloc[:,-1:].values

# %%
x5.shape,y5.shape
# Out:
# ((1181, 6), (1181, 1))

# %%
x5_train, x5_test, y5_train, y5_test = train_test_split(x5,y5, test_size=0.2, random_state=10)

# %%
x5_train.shape, x5_test.shape, y5_train.shape, y5_test.shape
# Out:
# ((944, 6), (237, 6), (944, 1), (237, 1))

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\programdata\anaconda3\lib\site-packages (1.7.5)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
xgb_model = xgb.XGBRegressor()

# %%
xgb_model.fit(x5_train, y5_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y5_pred = xgb_model.predict(x5_test)

# %%
xgb_model.score(x5_train, y5_train)
# Out:
# 0.9825696281037538

# %%
xgb_model.score(x5_test, y5_test)
# Out:
# 0.620015317560313

# %%
plt.plot(y5_test, label='original')
plt.plot(y5_pred, label = 'predicted')
plt.legend()
plt.show()

# %%
metrics.r2_score(y5_test,y5_pred)
# Out:
# 0.620015317560313

# %%
input_data = (30,0,32.4,1,0,3)

input_data_as_npa = np.asarray(input_data)

input_data_reshaped = input_data_as_npa.reshape(1,-1)

prediction = lr.predict(input_data_reshaped)

print(prediction)
# Out:
# [5705.44686342]
